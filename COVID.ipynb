# %%
import pandas as pd

# Fetch new data for each run.
vaccination_positive = pd.read_csv("https://onemocneni-aktualne.mzcr.cz/api/v2/covid-19/ockovani-pozitivni.csv")
vaccination_deaths = pd.read_csv("https://onemocneni-aktualne.mzcr.cz/api/v2/covid-19/ockovani-umrti.csv")
vaccination_hospitalization = pd.read_csv("https://onemocneni-aktualne.mzcr.cz/api/v2/covid-19/ockovani-hospitalizace.csv")

# %%
# Left for some additional information

# %%
vaccination_deaths.info()
vaccination_deaths.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308 entries, 0 to 307
# Data columns (total 14 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   datum                                         308 non-null    object
#  1   zemreli_celkem                                308 non-null    int64
#  2   zemreli_bez_ockovani                          308 non-null    int64
#  3   zemreli_bez_ockovani_relativni_pocet          308 non-null    float64
#  4   zemreli_bez_ockovani_vek_prumer               245 non-null    float64
#  5   zemreli_nedokoncene_ockovani                  308 non-null    int64
#  6   zemreli_nedokoncene_ockovani_relativni_pocet  308 non-null    float64
#  7   zemreli_nedokoncene_ockovani_vek_prumer       158 non-null    float64
#  8   zemreli_dokoncene_ockovani                    308 non-null    int64
#  9   zemreli_dokoncene_ockovani_relativni_pocet    308 non-null    float64
#  10  zemreli_dokoncene_ockovani_vek_prumer         123 non-null    float64
#  11  zemreli_posilujici_davka                      308 non-null    int64
#  12  zemreli_posilujici_davka_relativni_pocet      308 non-null    float64
#  13  zemreli_posilujici_davka_vek_prumer           0 non-null      float64
# dtypes: float64(8), int64(5), object(1)
# memory usage: 33.8+ KB
#           datum  zemreli_celkem  zemreli_bez_ockovani  \
# 291  2021-10-19              10                     6
# 171  2021-06-21               1                     0
# 259  2021-09-17               2                     2
# 75   2021-03-17             198                   179
# 87   2021-03-29             180                   155
# 1    2021-01-02             152                   152
# 121  2021-05-02              34                    28
# 44   2021-02-14             149                   141
# 58   2021-02-28             183                   172
# 155  2021-06-05               2                     2
#
#      zemreli_bez_ockovani_relativni_pocet  zemreli_bez_ockovani_vek_prumer  \
# 291                              0.600000                             76.0
# 171                              0.000000                              NaN
# 259                              1.000000                             53.0
# 75                               0.904040                             74.0
# 87                               0.861111                             74.0
# 1                                1.000000                             79.0
# 121                              0.823529                             70.0
# 44                               0.946309                             73.0
# 58                               0.939891                             75.0
# 155                              1.000000                             76.0
#
#      zemreli_nedokoncene_ockovani  \
# 291                             0
# 171                             0
# 259                             0
# 75                             18
# 87                             22
# 1                               0
# 121                             4
# 44                              8
# 58                             11
# 155                             0
#
#      zemreli_nedokoncene_ockovani_relativni_pocet  \
# 291                                      0.000000
# 171                                      0.000000
# 259                                      0.000000
# 75                                       0.090909
# 87                                       0.122222
# 1                                        0.000000
# 121                                      0.117647
# 44                                       0.053691
# 58                                       0.060109
# 155                                      0.000000
#
#      zemreli_nedokoncene_ockovani_vek_prumer  zemreli_dokoncene_ockovani  \
# 291                                      NaN                           4
# 171                                      NaN                           1
# 259                                      NaN                           0
# 75                                      78.0                           1
# 87                                      78.0                           3
# 1                                        NaN                           0
# 121                                     82.0                           2
# 44                                      89.0                           0
# 58                                      86.0                           0
# 155                                      NaN                           0
#
#      zemreli_dokoncene_ockovani_relativni_pocet  \
# 291                                    0.400000
# 171                                    1.000000
# 259                                    0.000000
# 75                                     0.005051
# 87                                     0.016667
# 1                                      0.000000
# 121                                    0.058824
# 44                                     0.000000
# 58                                     0.000000
# 155                                    0.000000
#
#      zemreli_dokoncene_ockovani_vek_prumer  zemreli_posilujici_davka  \
# 291                                   80.0                         0
# 171                                   87.0                         0
# 259                                    NaN                         0
# 75                                    72.0                         0
# 87                                    88.0                         0
# 1                                      NaN                         0
# 121                                   88.0                         0
# 44                                     NaN                         0
# 58                                     NaN                         0
# 155                                    NaN                         0
#
#      zemreli_posilujici_davka_relativni_pocet  \
# 291                                       0.0
# 171                                       0.0
# 259                                       0.0
# 75                                        0.0
# 87                                        0.0
# 1                                         0.0
# 121                                       0.0
# 44                                        0.0
# 58                                        0.0
# 155                                       0.0
#
#      zemreli_posilujici_davka_vek_prumer
# 291                                  NaN
# 171                                  NaN
# 259                                  NaN
# 75                                   NaN
# 87                                   NaN
# 1                                    NaN
# 121                                  NaN
# 44                                   NaN
# 58                                   NaN
# 155                                  NaN

# %%
vaccination_positive.info()
vaccination_positive.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308 entries, 0 to 307
# Data columns (total 14 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   datum                                           308 non-null    object
#  1   pozitivni_celkem                                308 non-null    int64
#  2   pozitivni_bez_ockovani                          308 non-null    int64
#  3   pozitivni_bez_ockovani_relativni_pocet          308 non-null    float64
#  4   pozitivni_bez_ockovani_vek_prumer               307 non-null    float64
#  5   pozitivni_nedokoncene_ockovani                  308 non-null    int64
#  6   pozitivni_nedokoncene_ockovani_relativni_pocet  308 non-null    float64
#  7   pozitivni_nedokoncene_ockovani_vek_prumer       307 non-null    float64
#  8   pozitivni_dokoncene_ockovani                    308 non-null    int64
#  9   pozitivni_dokoncene_ockovani_relativni_pocet    308 non-null    float64
#  10  pozitivni_dokoncene_ockovani_vek_prumer         266 non-null    float64
#  11  pozitivni_posilujici_davka                      308 non-null    int64
#  12  pozitivni_posilujici_davka_relativni_pocet      308 non-null    float64
#  13  pozitivni_posilujici_davka_vek_prumer           13 non-null     float64
# dtypes: float64(8), int64(5), object(1)
# memory usage: 33.8+ KB
#           datum  pozitivni_celkem  pozitivni_bez_ockovani  \
# 140  2021-05-21               672                     556
# 187  2021-07-07               280                     191
# 58   2021-02-28              4594                    4530
# 60   2021-03-02             16807                   16535
# 228  2021-08-17               300                     235
# 221  2021-08-10               260                     213
# 296  2021-10-24              1833                    1307
# 53   2021-02-23             15853                   15641
# 139  2021-05-20               678                     566
# 3    2021-01-04             12964                   12937
#
#      pozitivni_bez_ockovani_relativni_pocet  \
# 140                                0.827381
# 187                                0.682143
# 58                                 0.986069
# 60                                 0.983816
# 228                                0.783333
# 221                                0.819231
# 296                                0.713039
# 53                                 0.986627
# 139                                0.834808
# 3                                  0.997917
#
#      pozitivni_bez_ockovani_vek_prumer  pozitivni_nedokoncene_ockovani  \
# 140                               33.0                             105
# 187                               29.0                              77
# 58                                39.0                              48
# 60                                41.0                             218
# 228                               29.0                              35
# 221                               28.0                              27
# 296                               26.0                              23
# 53                                40.0                             190
# 139                               35.0                             101
# 3                                 45.0                              27
#
#      pozitivni_nedokoncene_ockovani_relativni_pocet  \
# 140                                        0.156250
# 187                                        0.275000
# 58                                         0.010448
# 60                                         0.012971
# 228                                        0.116667
# 221                                        0.103846
# 296                                        0.012548
# 53                                         0.011985
# 139                                        0.148968
# 3                                          0.002083
#
#      pozitivni_nedokoncene_ockovani_vek_prumer  pozitivni_dokoncene_ockovani  \
# 140                                       59.0                            11
# 187                                       36.0                            12
# 58                                        68.0                            16
# 60                                        67.0                            54
# 228                                       34.0                            30
# 221                                       26.0                            20
# 296                                       34.0                           502
# 53                                        67.0                            22
# 139                                       60.0                            11
# 3                                         45.0                             0
#
#      pozitivni_dokoncene_ockovani_relativni_pocet  \
# 140                                      0.016369
# 187                                      0.042857
# 58                                       0.003483
# 60                                       0.003213
# 228                                      0.100000
# 221                                      0.076923
# 296                                      0.273868
# 53                                       0.001388
# 139                                      0.016224
# 3                                        0.000000
#
#      pozitivni_dokoncene_ockovani_vek_prumer  pozitivni_posilujici_davka  \
# 140                                     68.0                           0
# 187                                     55.0                           0
# 58                                      51.0                           0
# 60                                      67.0                           0
# 228                                     55.0                           0
# 221                                     45.0                           0
# 296                                     49.0                           1
# 53                                      50.0                           0
# 139                                     68.0                           0
# 3                                        NaN                           0
#
#      pozitivni_posilujici_davka_relativni_pocet  \
# 140                                    0.000000
# 187                                    0.000000
# 58                                     0.000000
# 60                                     0.000000
# 228                                    0.000000
# 221                                    0.000000
# 296                                    0.000546
# 53                                     0.000000
# 139                                    0.000000
# 3                                      0.000000
#
#      pozitivni_posilujici_davka_vek_prumer
# 140                                    NaN
# 187                                    NaN
# 58                                     NaN
# 60                                     NaN
# 228                                    NaN
# 221                                    NaN
# 296                                   65.0
# 53                                     NaN
# 139                                    NaN
# 3                                      NaN

# %%
vaccination_hospitalization.info()
vaccination_hospitalization.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308 entries, 0 to 307
# Data columns (total 14 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   datum                                                 308 non-null    datetime64[ns]
#  1   hospitalizovani_celkem                                308 non-null    int64
#  2   hospitalizovani_bez_ockovani                          308 non-null    int64
#  3   hospitalizovani_bez_ockovani_relativni_pocet          308 non-null    float64
#  4   hospitalizovani_bez_ockovani_vek_prumer               304 non-null    float64
#  5   hospitalizovani_nedokoncene_ockovani                  308 non-null    int64
#  6   hospitalizovani_nedokoncene_ockovani_relativni_pocet  308 non-null    float64
#  7   hospitalizovani_nedokoncene_ockovani_vek_prumer       222 non-null    float64
#  8   hospitalizovani_dokoncene_ockovani                    308 non-null    int64
#  9   hospitalizovani_dokoncene_ockovani_relativni_pocet    308 non-null    float64
#  10  hospitalizovani_dokoncene_ockovani_vek_prumer         221 non-null    float64
#  11  hospitalizovani_posilujici_davka                      308 non-null    int64
#  12  hospitalizovani_posilujici_davka_relativni_pocet      308 non-null    float64
#  13  hospitalizovani_posilujici_davka_vek_prumer           5 non-null      float64
# dtypes: datetime64[ns](1), float64(8), int64(5)
# memory usage: 33.8 KB
#          datum  hospitalizovani_celkem  hospitalizovani_bez_ockovani  \
# 88  2021-03-29                     786                           695
# 26  2021-01-27                     584                           546
# 132 2021-05-12                     137                           108
# 250 2021-09-08                      15                            12
# 256 2021-09-14                      23                            18
# 20  2021-01-21                     575                           567
# 95  2021-04-05                     365                           318
# 147 2021-05-27                      38                            27
# 89  2021-03-30                     651                           560
# 101 2021-04-11                     282                           242
#
#      hospitalizovani_bez_ockovani_relativni_pocet  \
# 88                                       0.884224
# 26                                       0.934932
# 132                                      0.788321
# 250                                      0.800000
# 256                                      0.782609
# 20                                       0.986087
# 95                                       0.871233
# 147                                      0.710526
# 89                                       0.860215
# 101                                      0.858156
#
#      hospitalizovani_bez_ockovani_vek_prumer  \
# 88                                      64.0
# 26                                      71.0
# 132                                     60.0
# 250                                     51.0
# 256                                     56.0
# 20                                      69.0
# 95                                      65.0
# 147                                     66.0
# 89                                      64.0
# 101                                     62.0
#
#      hospitalizovani_nedokoncene_ockovani  \
# 88                                     81
# 26                                     38
# 132                                    19
# 250                                     0
# 256                                     0
# 20                                      8
# 95                                     44
# 147                                     7
# 89                                     84
# 101                                    34
#
#      hospitalizovani_nedokoncene_ockovani_relativni_pocet  \
# 88                                            0.103053
# 26                                            0.065068
# 132                                           0.138686
# 250                                           0.000000
# 256                                           0.000000
# 20                                            0.013913
# 95                                            0.120548
# 147                                           0.184211
# 89                                            0.129032
# 101                                           0.120567
#
#      hospitalizovani_nedokoncene_ockovani_vek_prumer  \
# 88                                              77.0
# 26                                              80.0
# 132                                             70.0
# 250                                              NaN
# 256                                              NaN
# 20                                              85.0
# 95                                              76.0
# 147                                             61.0
# 89                                              77.0
# 101                                             77.0
#
#      hospitalizovani_dokoncene_ockovani  \
# 88                                   10
# 26                                    0
# 132                                  10
# 250                                   3
# 256                                   5
# 20                                    0
# 95                                    3
# 147                                   4
# 89                                    7
# 101                                   6
#
#      hospitalizovani_dokoncene_ockovani_relativni_pocet  \
# 88                                            0.012723
# 26                                            0.000000
# 132                                           0.072993
# 250                                           0.200000
# 256                                           0.217391
# 20                                            0.000000
# 95                                            0.008219
# 147                                           0.105263
# 89                                            0.010753
# 101                                           0.021277
#
#      hospitalizovani_dokoncene_ockovani_vek_prumer  \
# 88                                            81.0
# 26                                             NaN
# 132                                           84.0
# 250                                           71.0
# 256                                           82.0
# 20                                             NaN
# 95                                            71.0
# 147                                           77.0
# 89                                            77.0
# 101                                           84.0
#
#      hospitalizovani_posilujici_davka  \
# 88                                  0
# 26                                  0
# 132                                 0
# 250                                 0
# 256                                 0
# 20                                  0
# 95                                  0
# 147                                 0
# 89                                  0
# 101                                 0
#
#      hospitalizovani_posilujici_davka_relativni_pocet  \
# 88                                                0.0
# 26                                                0.0
# 132                                               0.0
# 250                                               0.0
# 256                                               0.0
# 20                                                0.0
# 95                                                0.0
# 147                                               0.0
# 89                                                0.0
# 101                                               0.0
#
#      hospitalizovani_posilujici_davka_vek_prumer
# 88                                           NaN
# 26                                           NaN
# 132                                          NaN
# 250                                          NaN
# 256                                          NaN
# 20                                           NaN
# 95                                           NaN
# 147                                          NaN
# 89                                           NaN
# 101                                          NaN

# %%
# Turn 'datum' column into datetime
vaccination_positive['datum'] = pd.to_datetime(vaccination_positive['datum'], yearfirst=True)
vaccination_deaths['datum'] = pd.to_datetime(vaccination_deaths['datum'], yearfirst=True)
vaccination_hospitalization['datum'] = pd.to_datetime(vaccination_hospitalization['datum'], yearfirst=True)

# %%
print(
    vaccination_positive['datum'][0],
    vaccination_deaths['datum'][0],
    vaccination_hospitalization['datum'][0]
)
# Out:
# 2021-01-01 00:00:00 2021-01-01 00:00:00 2021-01-01 00:00:00

# %%
# Only taking in account last 'wave', which we will unofficially start from 01.09.2021
vaccination_positive = vaccination_positive[vaccination_positive['datum'] >= '2021-09-01'].head(vaccination_positive.shape[0] - 1)
vaccination_deaths = vaccination_deaths[vaccination_deaths['datum'] >= '2021-09-01'].head(vaccination_deaths.shape[0] - 1)
vaccination_hospitalization = vaccination_hospitalization[vaccination_hospitalization['datum'] >= '2021-09-01'].head(vaccination_hospitalization.shape[0] - 1)

# %%
import matplotlib.pyplot as plt
# a little test

plt.figure(figsize=(14, 7))
plt.plot(vaccination_positive['datum'], vaccination_positive['pozitivni_dokoncene_ockovani_relativni_pocet'])

plt.title("COVID Pozitivni od zari.")
plt.xlabel('Datum')
plt.ylabel('Pozitivni celkem')

plt.grid()
plt.show()

# %%
plt.figure(figsize=(20, 10))

plt.plot(vaccination_positive['datum'], vaccination_positive['pozitivni_dokoncene_ockovani_relativni_pocet'], label="Pozitivni ockovani")
plt.plot(vaccination_hospitalization['datum'], vaccination_hospitalization['hospitalizovani_dokoncene_ockovani_relativni_pocet'], label="Hospitalizovani ockovani")
plt.plot(vaccination_deaths['datum'], vaccination_deaths['zemreli_dokoncene_ockovani_relativni_pocet'], label="Umrti ockovani")

plt.title("Relativni pocet ockovanych mezi nakazenymi, hospitalizacemi a umrtimi.")
plt.legend()
plt.show()
